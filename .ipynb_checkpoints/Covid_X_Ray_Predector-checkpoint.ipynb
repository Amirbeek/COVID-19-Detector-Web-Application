# %%
import os
import pathlib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import random
import cv2
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Activation, Conv2D, MaxPool2D, Flatten, Dropout, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping
import tensorflow as tf
from sklearn.metrics import classification_report, confusion_matrix

# %%
for dirpath, dirname, filenames in os.walk('COVID_IEEE'):
    print(f'there are {len(filenames)} files in {dirpath}')

# %%
data_dir = pathlib.Path(r'C:\Users\acer predator\Desktop\Covid_model\COVID_IEEE')
class_name = np.array([sorted(item.name for item in data_dir.glob("*"))])
class_name
# Out:
# array([['covid', 'normal', 'virus']], dtype='<U6')

# %%
def view_image(target, target_class):
    target_folder = os.path.join(target, target_class)  
    random_image = random.sample(os.listdir(target_folder), 1)[0] 
    print(random_image)  # Print the name of the random image
    img = mpimg.imread(os.path.join(target_folder, random_image))  # Correctly join the path to read the image
    plt.imshow(img)
    plt.title(target_class)
    plt.axis("off")
    plt.show()
    return img

# %%
img =  view_image(data_dir, 'virus')
# Out:
# person931_virus_1592.jpeg

# %%
img =  view_image(data_dir, 'normal')
# Out:
# NORMAL2-IM-0730-0001.jpeg

# %%
data = []
labels = []

for category, label in zip(['covid', 'normal', 'virus'], [0, 1, 2]):
    category_dir = os.listdir(f"{data_dir}/{category}")
    for image_file in category_dir:
        image_path = f"{data_dir}/{category}/{image_file}"
        image = cv2.imread(image_path)
        if image is not None:
            image = cv2.resize(image, (224, 224))
            data.append(image)
            labels.append(label)
        else:
            print(f"Warning: Could not read image {image_path}")

# %%
img_data = np.array(data) / 255.0 # this is for normalize the data , i need to devide for 255
img_labels = np.array(labels)

# %%
X_train, X_test, y_train, y_test = train_test_split(data, img_labels, test_size=0.20, random_state=42)

# %%
X_train = np.array(X_train) / 255.0
X_test = np.array(X_test) / 255.0
y_train = tf.keras.utils.to_categorical(y_train, num_classes=3)
y_test = tf.keras.utils.to_categorical(y_test, num_classes=3)

# %%
model = Sequential()

#Block Number 1
model.add(Conv2D(input_shape = (224,224,3), filters=32 ,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))

model.add(Conv2D(filters=32,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))

model.add(MaxPool2D((2,2)))

#Block Number 2
model.add(Conv2D(filters=64,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))


model.add(Conv2D(filters=64,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))

model.add(MaxPool2D((2,2)))

#Block Number 3
model.add(Conv2D(filters=128,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))

model.add(Conv2D(filters=128,padding="same", kernel_size= (3,3)))
model.add(Activation("relu"))

model.add(MaxPool2D((2,2)))

model.add(MaxPool2D((2,2)))

# Fully Connected layer
model.add(Flatten())

model.add(Dense(units=1024, activation="relu"))

model.add(Dense(units=256, activation="relu"))


model.add(Dense(units=3, activation="softmax"))

model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])
# Out:
# C:\Python310\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 224, 224, 32)   │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_1 (Activation)       │ (None, 224, 224, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 64)   │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_2 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 112, 112, 64)   │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_3 (Activation)       │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 56, 56, 128)    │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_4 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 56, 56, 128)    │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation_5 (Activation)       │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_3 (MaxPooling2D)  │ (None, 14, 14, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 25088)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1024)           │    25,691,136 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       262,400 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 26,241,315 (100.10 MB)
#  Trainable params: 26,241,315 (100.10 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 62s 2s/step - accuracy: 0.5103 - loss: 1.1560 - val_accuracy: 0.6941 - val_loss: 0.6885
# Epoch 2/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8245 - loss: 0.5054 - val_accuracy: 0.8790 - val_loss: 0.3370
# Epoch 3/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.8884 - loss: 0.2996 - val_accuracy: 0.9018 - val_loss: 0.2954
# Epoch 4/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9335 - loss: 0.1932 - val_accuracy: 0.9178 - val_loss: 0.2544
# Epoch 5/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 53s 2s/step - accuracy: 0.9642 - loss: 0.1273 - val_accuracy: 0.9224 - val_loss: 0.2013
# Epoch 6/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 54s 2s/step - accuracy: 0.9722 - loss: 0.0910 - val_accuracy: 0.9315 - val_loss: 0.2285
# Epoch 7/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.9456 - loss: 0.1399 - val_accuracy: 0.9247 - val_loss: 0.2113
# Epoch 8/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 82s 3s/step - accuracy: 0.9675 - loss: 0.0931 - val_accuracy: 0.9384 - val_loss: 0.2342
# Epoch 9/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 83s 3s/step - accuracy: 0.9712 - loss: 0.0750 - val_accuracy: 0.9361 - val_loss: 0.2239
# Epoch 10/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 88s 3s/step - accuracy: 0.9783 - loss: 0.0549 - val_accuracy: 0.9269 - val_loss: 0.2155
# Epoch 11/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 92s 3s/step - accuracy: 0.9685 - loss: 0.0732 - val_accuracy: 0.9429 - val_loss: 0.2415
# Epoch 12/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 90s 3s/step - accuracy: 0.9976 - loss: 0.0119 - val_accuracy: 0.9406 - val_loss: 0.2860
# Epoch 13/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 94s 3s/step - accuracy: 0.9723 - loss: 0.0622 - val_accuracy: 0.9110 - val_loss: 0.3383
# Epoch 14/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 105s 3s/step - accuracy: 0.9716 - loss: 0.0606 - val_accuracy: 0.9498 - val_loss: 0.2818
# Epoch 15/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 118s 4s/step - accuracy: 0.9877 - loss: 0.0261 - val_accuracy: 0.9292 - val_loss: 0.3288

# %%
#saving the models history
loss = pd.DataFrame(model.history.history)

#plotting the loss and accuracy 
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot(loss["loss"], label ="Loss")
plt.plot(loss["val_loss"], label = "Validation_loss")
plt.legend()
plt.title("Training and Validation Loss")

plt.subplot(2,2,2)
plt.plot(loss['accuracy'],label = "Training Accuracy")
plt.plot(loss['val_accuracy'], label ="Validation_ Accuracy ")
plt.legend()
plt.title("Training-Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Training-Validation Accuracy')

# %%
predictions = model.predict(X_test)
y_pred = np.argmax(predictions, axis = 1)
y_test_new = np.argmax(y_test, axis = 1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 9s 782ms/step

# %%
print(classification_report(y_test_new, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.94      0.95      0.94       108
#            1       0.90      0.95      0.93       129
#            2       0.95      0.88      0.91       128
#
#     accuracy                           0.93       365
#    macro avg       0.93      0.93      0.93       365
# weighted avg       0.93      0.93      0.93       365

# %%
pd.DataFrame(confusion_matrix(y_test_new, y_pred),
             columns= ["covid", "normal", "virus"], index = ["covid", "normal", "virus"])
# Out:
#         covid  normal  virus
# covid     103       2      3
# normal      3     123      3
# virus       4      11    113

# %%
import tensorflow as tf

weights_path = '../mobilenet_1_0_224_tf_no_top.h5'

base_model = tf.keras.applications.MobileNet(input_shape=[224, 224, 3], weights=weights_path, include_top=False)

for layer in base_model.layers:
    layer.trainable = False

# %%
model = Flatten()(base_model.output)

model = Dense(units=1024, activation="relu")(model)
model = Dense(units=512, activation="relu")(model)
model = Dense(units=256, activation="relu")(model)

prediction_layer = Dense(units=3, activation="softmax")(model)

# %%
model = Model(inputs = base_model.input, outputs = prediction_layer)
model.compile(optimizer='adam',loss='categorical_crossentropy',metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "functional_20"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_3 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1 (Conv2D)                  │ (None, 112, 112, 32)   │           864 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_bn (BatchNormalization)   │ (None, 112, 112, 32)   │           128 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1_relu (ReLU)               │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1 (DepthwiseConv2D)     │ (None, 112, 112, 32)   │           288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_bn                    │ (None, 112, 112, 32)   │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_1_relu (ReLU)           │ (None, 112, 112, 32)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1 (Conv2D)              │ (None, 112, 112, 64)   │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_bn                    │ (None, 112, 112, 64)   │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_1_relu (ReLU)           │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_2 (ZeroPadding2D)      │ (None, 113, 113, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2 (DepthwiseConv2D)     │ (None, 56, 56, 64)     │           576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_bn                    │ (None, 56, 56, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_2_relu (ReLU)           │ (None, 56, 56, 64)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2 (Conv2D)              │ (None, 56, 56, 128)    │         8,192 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_2_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3 (DepthwiseConv2D)     │ (None, 56, 56, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3 (Conv2D)              │ (None, 56, 56, 128)    │        16,384 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_bn                    │ (None, 56, 56, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_3_relu (ReLU)           │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_4 (ZeroPadding2D)      │ (None, 57, 57, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4 (DepthwiseConv2D)     │ (None, 28, 28, 128)    │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_bn                    │ (None, 28, 28, 128)    │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_4_relu (ReLU)           │ (None, 28, 28, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4 (Conv2D)              │ (None, 28, 28, 256)    │        32,768 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_4_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5 (DepthwiseConv2D)     │ (None, 28, 28, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5 (Conv2D)              │ (None, 28, 28, 256)    │        65,536 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_bn                    │ (None, 28, 28, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_5_relu (ReLU)           │ (None, 28, 28, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_6 (ZeroPadding2D)      │ (None, 29, 29, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6 (DepthwiseConv2D)     │ (None, 14, 14, 256)    │         2,304 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_bn                    │ (None, 14, 14, 256)    │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_6_relu (ReLU)           │ (None, 14, 14, 256)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6 (Conv2D)              │ (None, 14, 14, 512)    │       131,072 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_6_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_7_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_8_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9 (DepthwiseConv2D)     │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9 (Conv2D)              │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_bn                    │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_9_relu (ReLU)           │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_10_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11 (DepthwiseConv2D)    │ (None, 14, 14, 512)    │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11 (Conv2D)             │ (None, 14, 14, 512)    │       262,144 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_bn                   │ (None, 14, 14, 512)    │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_11_relu (ReLU)          │ (None, 14, 14, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pad_12 (ZeroPadding2D)     │ (None, 15, 15, 512)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12 (DepthwiseConv2D)    │ (None, 7, 7, 512)      │         4,608 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_bn                   │ (None, 7, 7, 512)      │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_12_relu (ReLU)          │ (None, 7, 7, 512)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12 (Conv2D)             │ (None, 7, 7, 1024)     │       524,288 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_12_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13 (DepthwiseConv2D)    │ (None, 7, 7, 1024)     │         9,216 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_dw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13 (Conv2D)             │ (None, 7, 7, 1024)     │     1,048,576 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_bn                   │ (None, 7, 7, 1024)     │         4,096 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv_pw_13_relu (ReLU)          │ (None, 7, 7, 1024)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten_2 (Flatten)             │ (None, 50176)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 1024)           │    51,381,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 512)            │       524,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 3)              │           771 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 55,267,011 (210.83 MB)
#  Trainable params: 52,038,147 (198.51 MB)
#  Non-trainable params: 3,228,864 (12.32 MB)

# %%
model.fit(X_train, y_train, validation_split=0.3, epochs=15, batch_size=32)
# Out:
# Epoch 1/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 27s 610ms/step - accuracy: 0.6809 - loss: 12.2933 - val_accuracy: 0.9201 - val_loss: 1.6188
# Epoch 2/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 586ms/step - accuracy: 0.9244 - loss: 1.1226 - val_accuracy: 0.9429 - val_loss: 0.8557
# Epoch 3/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 609ms/step - accuracy: 0.9728 - loss: 0.2625 - val_accuracy: 0.9521 - val_loss: 0.9246
# Epoch 4/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 584ms/step - accuracy: 0.9902 - loss: 0.2010 - val_accuracy: 0.9612 - val_loss: 0.9176
# Epoch 5/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 570ms/step - accuracy: 0.9959 - loss: 0.0955 - val_accuracy: 0.9566 - val_loss: 0.8366
# Epoch 6/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 562ms/step - accuracy: 0.9957 - loss: 0.0295 - val_accuracy: 0.9475 - val_loss: 0.6975
# Epoch 7/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 601ms/step - accuracy: 0.9993 - loss: 0.0036 - val_accuracy: 0.9566 - val_loss: 0.8101
# Epoch 8/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 620ms/step - accuracy: 0.9912 - loss: 0.0377 - val_accuracy: 0.9612 - val_loss: 0.6281
# Epoch 9/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 20s 637ms/step - accuracy: 0.9970 - loss: 0.0207 - val_accuracy: 0.9566 - val_loss: 1.1099
# Epoch 10/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 606ms/step - accuracy: 0.9984 - loss: 0.0152 - val_accuracy: 0.9269 - val_loss: 1.9958
# Epoch 11/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 19s 586ms/step - accuracy: 0.9707 - loss: 0.2021 - val_accuracy: 0.9521 - val_loss: 0.9602
# Epoch 12/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 575ms/step - accuracy: 0.9955 - loss: 0.0390 - val_accuracy: 0.9384 - val_loss: 0.9165
# Epoch 13/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 577ms/step - accuracy: 0.9866 - loss: 0.1625 - val_accuracy: 0.9635 - val_loss: 0.9093
# Epoch 14/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 578ms/step - accuracy: 0.9950 - loss: 0.0879 - val_accuracy: 0.9635 - val_loss: 0.8973
# Epoch 15/15
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 18s 578ms/step - accuracy: 0.9935 - loss: 0.0547 - val_accuracy: 0.9566 - val_loss: 0.8696

# %%
#saving the models history
loss = pd.DataFrame(model.history.history)

#plotting the loss and accuracy 
plt.figure(figsize=(10,10))

plt.subplot(2,2,1)
plt.plot(loss["loss"], label ="Loss")
plt.plot(loss["val_loss"], label = "Validation_loss")
plt.legend()
plt.title("Training and Validation Loss")

plt.subplot(2,2,2)
plt.plot(loss['accuracy'],label = "Training Accuracy")
plt.plot(loss['val_accuracy'], label ="Validation_ Accuracy ")
plt.legend()
plt.title("Training-Validation Accuracy")
# Out:
# Text(0.5, 1.0, 'Training-Validation Accuracy')

# %%
predictions = model.predict(X_test)

y_pred = np.argmax(predictions, axis = 1)
y_test_new = np.argmax(y_test, axis = 1)
# Out:
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 237ms/step

# %%
pd.DataFrame(confusion_matrix(y_test_new, y_pred), columns= ["covid", "normal", "virus"], index = ["covid", "normal", "virus"])
# Out:
#         covid  normal  virus
# covid     104       2      2
# normal      0     122      7
# virus       0       6    122

# %%
import tensorflow as tf
import joblib  # Add this import to resolve the error

# After converting the model to TensorFlow Lite format
convertor = tf.lite.TFLiteConverter.from_keras_model(model)  # Your Keras model
tflite_model = convertor.convert()

# Save the labels (if you want to use them directly in the inference code)
labels = ['covid', 'normal', 'virus']  # List of class labels

# Save the labels using joblib
joblib.dump(labels, 'labels.joblib')  # Save the labels in a joblib file

# Save the TensorFlow Lite model
with open('../models/Covid_X_Ray_Predictor2.tflite', 'wb') as f:  # Save the .tflite model
    f.write(tflite_model)

print("Model and labels saved successfully.")
# Out:
# INFO:tensorflow:Assets written to: C:\Users\ACERPR~1\AppData\Local\Temp\tmpfzyherww\assets
# INFO:tensorflow:Assets written to: C:\Users\ACERPR~1\AppData\Local\Temp\tmpfzyherww\assets
# Saved artifact at 'C:\Users\ACERPR~1\AppData\Local\Temp\tmpfzyherww'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_383')
# Output Type:
#   TensorSpec(shape=(None, 3), dtype=tf.float32, name=None)
# Captures:
#   3171868398288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176915836368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176915844464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176915834960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176915843936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176915829504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916209856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916212496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916208448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916210384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916218304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916217248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916219888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916215840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916217776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916208800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916308160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916310800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916306752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916308688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916316608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916315552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916318192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916314144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916316080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916307104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916175856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916178320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916173744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916177264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916184128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916183072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916185712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916181664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916183600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916173920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916225008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916227472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916222896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916226416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916233280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916232224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916234864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916230816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916232752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916237504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916288784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916288432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916291072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916290544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916297408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916296352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916298992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916294944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916296880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916303040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916387088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916386736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916389376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916388848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916395712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916394656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916397296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916393248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916395184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916399936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916468656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916467952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916400992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916467776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916393600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916475168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916477808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916473760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916475696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916483616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916480096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916479392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916480800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916479744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916474112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916539296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916541936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916537888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916539824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916547744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916546688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916549328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916545280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916547216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916538240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916652576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916655216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916651168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916653104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916661024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916659968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916662608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916658560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916660496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916651520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916749472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916752112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916748064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916750000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916757920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916756864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916759504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916755456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916757392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916762144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916797040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916796864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916798272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916798800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916807072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916806016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916808656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916804608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916806544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916811296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916911728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916911552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916912960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916913488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916920352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916919296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916921936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916917888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916919824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916924576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176917025008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176917025184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176916926160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176917026768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176917038384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918631168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918638560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918634160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918641552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918636976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918644544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   3176918639968: TensorSpec(shape=(), dtype=tf.resource, name=None)
# Model and labels saved successfully.
